# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
class BatsmanState(TypedDict):

    runs: int
    balls: int
    fours: int
    sixes: int

    sr: float
    bpb: float
    boundary_percent: float
    summary: str

# %%
def calculate_sr(state: BatsmanState):

    sr = (state['runs']/state['balls'])/100

    state['sr'] = sr

    return {'sr': sr}

# %%
def calculate_bpb(state: BatsmanState):

    bpb = state['balls']/(state['four'] + state['sixes'])
    state['bpb'] = bpb
    return {'bpb': bpb}

# %%
def calculate_boundary_percent(state: BatsmanState):

    boundary_percent = (((state['fours'] * 4) + (state['sixes'] * 6))/state['runs'])* 100
    state['boundary_percent'] = boundary_percent

    return {'boundary_percent': boundary_percent}

# %%
def summary(state: BatsmanState):

    summary = f"""
Strike Rate - {state['sr']} \n
Balls per boundary - {state['bpb']} \n
Boundary percent - {state['boundary_percent']}
"""
    state['summary'] = summary
    return {'summary': summary}

# %%
graph = StateGraph(BatsmanState)

# crearting nodes
graph.add_node('calculate_sr', calculate_sr)
graph.add_node('calculate_bpb', calculate_sr)
graph.add_node('calculate_boundary_percent', calculate_boundary_percent)
graph.add_node('summary', summary)

# defining edges
graph.add_edge(START, 'calculate_sr')
graph.add_edge(START, 'calculate_bpb')
graph.add_edge(START, 'calculate_boundary_percent')

graph.add_edge('calculate_sr', 'summary')
graph.add_edge('calculate_bpb', 'summary')
graph.add_edge('calculate_boundary_percent', 'summary')

graph.add_edge('summary', END)

workflow = graph.compile()

# %%
initial_state = {
    'runs': 100,
    'balls': 50,
    'fours': 6,
    'sixes': 4
}

workflow.invoke(initial_state)
# Out:
# ---------------------------------------------------------------------------
# InvalidUpdateError                        Traceback (most recent call last)
# Cell In[28], line 8
#       4     'fours': 6,
#       5     'sixes': 4
#       6 }
#       7
# ----> 8 workflow.invoke(initial_state)
#
# File d:\AgenticAI\myenv\Lib\site-packages\langgraph\pregel\main.py:3309, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3306             chunks.append(chunk)
#    3307 else:
#    3308     # v1: collect interrupts from updates stream
# -> 3309     for chunk in self.stream(
#    3310         input,
#    3311         config,
#    3312         context=context,
#    3313         stream_mode=(
#    3314             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3315         ),
#    3316         print_mode=print_mode,
#    3317         output_keys=output_keys,
#    3318         interrupt_before=interrupt_before,
#    3319         interrupt_after=interrupt_after,
#    3320         durability=durability,
#    3321         **kwargs,
#    3322     ):
#    3323         if stream_mode == "values":
#    3324             if len(chunk) == 2:
#
# File d:\AgenticAI\myenv\Lib\site-packages\langgraph\pregel\main.py:2753, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2736 for _ in runner.tick(
#    2737     [t for t in loop.tasks.values() if not t.writes],
#    2738     timeout=self.step_timeout,
#    (...)   2741 ):
#    2742     # emit output
#    2743     yield from _output(
#    2744         stream_mode,
#    2745         print_mode,
#    (...)   2751         _state_mapper,
#    2752     )
# -> 2753 loop.after_tick()
#    2754 # wait for checkpoint
#    2755 if durability_ == "sync":
#
# File d:\AgenticAI\myenv\Lib\site-packages\langgraph\pregel\_loop.py:544, in PregelLoop.after_tick(self)
#     542 writes = [w for t in self.tasks.values() for w in t.writes]
#     543 # all tasks have finished
# --> 544 self.updated_channels = apply_writes(
#     545     self.checkpoint,
#     546     self.channels,
#     547     self.tasks.values(),
#     548     self.checkpointer_get_next_version,
#     549     self.trigger_to_nodes,
#     550 )
#     551 # produce values output
#     552 if not self.updated_channels.isdisjoint(
#     553     (self.output_keys,)
#     554     if isinstance(self.output_keys, str)
#     555     else self.output_keys
#     556 ):
#
# File d:\AgenticAI\myenv\Lib\site-packages\langgraph\pregel\_algo.py:297, in apply_writes(checkpoint, channels, tasks, get_next_version, trigger_to_nodes)
#     295 for chan, vals in pending_writes_by_channel.items():
#     296     if chan in channels:
# --> 297         if channels[chan].update(vals) and next_version is not None:
#     298             checkpoint["channel_versions"][chan] = next_version
#     299             # unavailable channels can't trigger tasks, so don't add them
#
# File d:\AgenticAI\myenv\Lib\site-packages\langgraph\channels\last_value.py:64, in LastValue.update(self, values)
#      59 if len(values) != 1:
#      60     msg = create_error_message(
#      61         message=f"At key '{self.key}': Can receive only one value per step. Use an Annotated key to handle multiple values.",
#      62         error_code=ErrorCode.INVALID_CONCURRENT_GRAPH_UPDATE,
#      63     )
# ---> 64     raise InvalidUpdateError(msg)
#      66 self.value = values[-1]
#      67 return True
#
# InvalidUpdateError: At key 'sr': Can receive only one value per step. Use an Annotated key to handle multiple values.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE
